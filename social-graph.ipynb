# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.read_edgelist("Dataset/facebook_combined/facebook_combined.txt")

# %%
layout = nx.spring_layout(G)
nx.draw(G, pos=layout, with_labels=False, node_size=10)
plt.show()
